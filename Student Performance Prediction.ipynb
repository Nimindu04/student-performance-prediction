# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv("student-mat.csv", sep=";")

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    str
#  1   sex         395 non-null    str
#  2   age         395 non-null    int64
#  3   address     395 non-null    str
#  4   famsize     395 non-null    str
#  5   Pstatus     395 non-null    str
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    str
#  9   Fjob        395 non-null    str
#  10  reason      395 non-null    str
#  11  guardian    395 non-null    str
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    str
#  16  famsup      395 non-null    str
#  17  paid        395 non-null    str
#  18  activities  395 non-null    str
#  19  nursery     395 non-null    str
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
target = "G3"

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df["G3"], bins=11, kde=True)

plt.title("Distribution of Final Grades")
plt.xlabel("Final Grade")
plt.ylabel("Number of Students")

plt.show()

# %% [markdown]
# ## important relationships

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(x="studytime", y="G3", data=df)

plt.title("Study Time vs Final Grade")
plt.xlabel("Study Time")
plt.ylabel("Final Grade")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(data=df, x="G2", y="G3")

plt.title("Previous Grade vs Final Grade")
plt.xlabel("Second Period Grade")
plt.ylabel("Final Grade")

plt.show()

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(10, 8))

numeric_df = df.select_dtypes(include=np.number)

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# ## Select features

# %%
features = [
    "age",
    "studytime",
    "failures",
    "absences",
    "G1",
    "G2",
    "goout",
    "health",
    "famrel"
]

X = df[features]
y = df["G3"]

# %% [markdown]
# ## Split the data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %% [markdown]
# ## Train Linear Regression

# %%
linear_model = LinearRegression()

linear_model.fit(X_train, y_train)

y_pred_linear = linear_model.predict(X_test)

# %% [markdown]
# ### Evaluate model

# %%
mae_linear = mean_absolute_error(y_test, y_pred_linear)
rmse_linear = np.sqrt(mean_squared_error(y_test, y_pred_linear))
r2_linear = r2_score(y_test, y_pred_linear)

print("Linear Regression")
print("MAE :", mae_linear)
print("RMSE:", rmse_linear)
print("R²  :", r2_linear)
# Out:
# Linear Regression
# MAE : 1.3579665185422467
# RMSE: 2.1202099962104604
# R²  : 0.7807715159461447

# %% [markdown]
# ## Train Random Forest

# %%
rf_model = RandomForestRegressor(n_estimators=200,random_state=42)

rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

# %% [markdown]
# ### Evaluate

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

print("Random Forest")
print("MAE :", mae_rf)
print("RMSE:", rmse_rf)
print("R²  :", r2_rf)
# Out:
# Random Forest
# MAE : 1.0628481012658226
# RMSE: 1.7563187010753016
# R²  : 0.8495660439392992

# %% [markdown]
# ## Train Gradient Boosting

# %%
gb_model = GradientBoostingRegressor(n_estimators=100,random_state=42)

gb_model.fit(X_train, y_train)

y_pred_gb = gb_model.predict(X_test)

# %% [markdown]
# ### Evaluate

# %%
mae_gb = mean_absolute_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(mean_squared_error(y_test, y_pred_gb))
r2_gb = r2_score(y_test, y_pred_gb)

print("Gradient Boosting")
print("MAE :", mae_gb)
print("RMSE:", rmse_gb)
print("R²  :", r2_gb)
# Out:
# Gradient Boosting
# MAE : 1.0934239714264886
# RMSE: 1.7709863514302104
# R²  : 0.8470428955393525

# %% [markdown]
# ## compare the models

# %%
results = pd.DataFrame({
    "Model": ["Linear Regression","Random Forest","Gradient Boosting"],
    "MAE": [mae_linear,mae_rf,mae_gb],
    "RMSE": [rmse_linear,rmse_rf,rmse_gb],
    "R2": [r2_linear,r2_rf,r2_gb]})

results
# Out:
#                Model       MAE      RMSE        R2
# 0  Linear Regression  1.357967  2.120210  0.780772
# 1      Random Forest  1.062848  1.756319  0.849566
# 2  Gradient Boosting  1.093424  1.770986  0.847043

# %%
plt.figure(figsize=(9, 5))

sns.barplot(data=results, x="Model", y="R2")

plt.title("Model Comparison - R² Score")
plt.xticks(rotation=15)

plt.show()

# %%
plt.figure(figsize=(9, 5))

sns.barplot(data=results, x="Model", y="MAE")

plt.title("Model Comparison - MAE")
plt.xticks(rotation=15)

plt.show()

# %%
plt.figure(figsize=(9, 5))

sns.barplot(data=results, x="Model", y="RMSE")

plt.title("Model Comparison - RMSE")
plt.xticks(rotation=15)

plt.show()

# %%
plt.figure(figsize=(7, 7))

plt.scatter(y_test, y_pred_linear, label="Linear Regression", alpha=0.7)

plt.xlabel("Actual Final Grade")
plt.ylabel("Predicted Final Grade")
plt.title("Actual vs Predicted Final Grades")

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.show()

# %%
plt.figure(figsize=(7, 7))

plt.scatter(y_test, y_pred_rf)

plt.xlabel("Actual Final Grade")
plt.ylabel("Predicted Final Grade")
plt.title("Actual vs Predicted Final Grades")

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.show()

# %%
plt.figure(figsize=(7, 7))

plt.scatter(y_test, y_pred_gb, alpha=0.7)

plt.xlabel("Actual Final Grade")
plt.ylabel("Predicted Final Grade")
plt.title("Actual vs Predicted Final Grades")

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    linestyle="--"
)

plt.show()

# %% [markdown]
# ## Make a prediction for a new student

# %%
new_student = pd.DataFrame({
    "age": [20],
    "studytime": [3],
    "failures": [0],
    "absences": [4],
    "G1": [15],
    "G2": [16],
    "goout": [3],
    "health": [4],
    "famrel": [4]
})

# Predictions
rf_prediction = rf_model.predict(new_student)
linear_prediction = linear_model.predict(new_student)
gb_prediction = gb_model.predict(new_student)

# Display results
print(f"Random Forest Predicted Final Grade: {rf_prediction[0]:.2f}")
print(f"Linear Regression Predicted Final Grade: {linear_prediction[0]:.2f}")
print(f"Gradient Boosting Predicted Final Grade: {gb_prediction[0]:.2f}")
# Out:
# Random Forest Predicted Final Grade: 15.88
# Linear Regression Predicted Final Grade: 15.58
# Gradient Boosting Predicted Final Grade: 15.88

# %% [markdown]
# ## Check feature importance for rf model

# %%
importance = pd.DataFrame({
    "Feature": features,
    "Importance": rf_model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#      Feature  Importance
# 5         G2    0.792998
# 3   absences    0.117013
# 0        age    0.028875
# 7     health    0.015263
# 8     famrel    0.014926
# 4         G1    0.012903
# 6      goout    0.008870
# 1  studytime    0.005082
# 2   failures    0.004070

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature"
)

plt.title("Random Forest Feature Importance")

plt.show()

# %% [markdown]
# ## Check feature importance for gb model

# %%
importance = pd.DataFrame({
    "Feature": features,
    "Importance": gb_model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#      Feature  Importance
# 5         G2    0.800806
# 3   absences    0.140713
# 0        age    0.020917
# 4         G1    0.016065
# 8     famrel    0.007532
# 7     health    0.005710
# 6      goout    0.004998
# 2   failures    0.001740
# 1  studytime    0.001519

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature"
)

plt.title("Gradient Boosting Feature Importance")

plt.show()

# %% [markdown]
# ## Check feature importance for linear model

# %%
importance_linear = pd.DataFrame({
    "Feature": features,
    "Coefficient": linear_model.coef_,
    "Absolute Importance": np.abs(linear_model.coef_)
})

importance_linear = importance_linear.sort_values(
    by="Absolute Importance",
    ascending=False
)

importance_linear
# Out:
#      Feature  Coefficient  Absolute Importance
# 5         G2     0.976756             0.976756
# 2   failures    -0.382075             0.382075
# 8     famrel     0.346329             0.346329
# 0        age    -0.188795             0.188795
# 4         G1     0.157112             0.157112
# 6      goout     0.143954             0.143954
# 1  studytime    -0.067036             0.067036
# 7     health     0.055872             0.055872
# 3   absences     0.045300             0.045300

# %%
plt.figure(figsize=(9, 5))

sns.barplot(
    data=importance_linear,
    x="Absolute Importance",
    y="Feature"
)

plt.title("Linear Regression Feature Importance")
plt.xlabel("Absolute Coefficient")
plt.ylabel("Feature")

plt.show()

# %%
new_student = pd.DataFrame({
    "age": [24],
    "studytime": [7],
    "failures": [0],
    "absences": [7],
    "G1": [10],
    "G2": [16],
    "goout": [3],
    "health": [5],
    "famrel": [4]
})

# Predictions
rf_prediction = rf_model.predict(new_student)
linear_prediction = linear_model.predict(new_student)
gb_prediction = gb_model.predict(new_student)

# Display results
print(f"Random Forest Predicted Final Grade: {rf_prediction[0]:.2f}")
print(f"Linear Regression Predicted Final Grade: {linear_prediction[0]:.2f}")
print(f"Gradient Boosting Predicted Final Grade: {gb_prediction[0]:.2f}")
# Out:
# Random Forest Predicted Final Grade: 15.62
# Linear Regression Predicted Final Grade: 13.96
# Gradient Boosting Predicted Final Grade: 13.52
